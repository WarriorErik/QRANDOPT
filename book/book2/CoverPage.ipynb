# %% [markdown]
# <div style="text-align: center; font-family: 'Georgia', serif; color: #2c3e50;">
#   <h1 style="font-size: 3.5em; margin-bottom: 0;">QRANDOPT</h1>
#   <h2 style="font-size: 2em; margin-top: 0; font-weight: 300;">Quantum Randomness Optimization</h2>
#   <p style="font-size: 1.2em; margin-top: 1em;">A Unified Dashboard for Noise Modeling, Extraction, Reinforcement Learning, and Quantum Optimization</p>
#   <p style="margin-top: 2em; font-size: 1em;">
#     <strong>Erik Recinos Jr.</strong><br/>
#     Defense: July 16, 2025<br/>
#     Advisor: Dr. Andreas Marpaung
#   </p>
#   <hr style="margin: 2em auto; width: 50%; border: 1px solid #bdc3c7;"/>
#
# </div>
